# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve


# 데이터 로드
train = pd.read_csv(r"C:\Users\lyr\kuggle_train.csv")
test = pd.read_csv(r"C:\Users\lyr\kuggle_test.csv")

# %%
train
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 0      Resort Hotel        342               2015               July
# 1      Resort Hotel        737               2015               July
# 2      Resort Hotel         13               2015               July
# 3      Resort Hotel         14               2015               July
# 4      Resort Hotel         14               2015               July
# ...             ...        ...                ...                ...
# 95506    City Hotel         23               2017             August
# 95507    City Hotel        102               2017             August
# 95508    City Hotel         34               2017             August
# 95509    City Hotel        109               2017             August
# 95510    City Hotel        205               2017             August
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 0                            27                          1
# 1                            27                          1
# 2                            27                          1
# 3                            27                          1
# 4                            27                          1
# ...                         ...                        ...
# 95506                        35                         30
# 95507                        35                         31
# 95508                        35                         31
# 95509                        35                         31
# 95510                        35                         29
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                            0                     0       2       0.0  ...
# 1                            0                     0       2       0.0  ...
# 2                            0                     1       1       0.0  ...
# 3                            0                     2       2       0.0  ...
# 4                            0                     2       2       0.0  ...
# ...                        ...                   ...     ...       ...  ...
# 95506                        2                     5       2       0.0  ...
# 95507                        2                     5       3       0.0  ...
# 95508                        2                     5       2       0.0  ...
# 95509                        2                     5       2       0.0  ...
# 95510                        2                     7       2       0.0  ...
#
#        customer_type     adr required_car_parking_spaces  \
# 0          Transient    0.00                           0
# 1          Transient    0.00                           0
# 2          Transient   75.00                           0
# 3          Transient   98.00                           0
# 4          Transient   98.00                           0
# ...              ...     ...                         ...
# 95506      Transient   96.14                           0
# 95507      Transient  225.43                           0
# 95508      Transient  157.71                           0
# 95509      Transient  104.40                           0
# 95510      Transient  151.20                           0
#
#       total_of_special_requests reservation_status                name  \
# 0                             0          Check-Out       Ernest Barnes
# 1                             0          Check-Out        Andrea Baker
# 2                             0          Check-Out        Laura Murray
# 3                             1          Check-Out         Linda Hines
# 4                             1          Check-Out    Jasmine Fletcher
# ...                         ...                ...                 ...
# 95506                         0          Check-Out     Claudia Johnson
# 95507                         2          Check-Out      Wesley Aguilar
# 95508                         4          Check-Out        Mary Morales
# 95509                         0          Check-Out  Caroline Conley MD
# 95510                         2          Check-Out      Ariana Michael
#
#                              email  phone-number       credit_card is_canceled
# 0      Ernest.Barnes31@outlook.com  669-792-1661  ************4322           0
# 1           Andrea_Baker94@aol.com  858-637-6955  ************9157           0
# 2                Laura_M@gmail.com  364-656-8427  ************5677           0
# 3               LHines@verizon.com  713-226-5883  ************5498           0
# 4          JFletcher43@xfinity.com  190-271-6743  ************9263           0
# ...                            ...           ...               ...         ...
# 95506          Claudia.J@yahoo.com  403-092-5582  ************8647           0
# 95507         WAguilar@xfinity.com  238-763-0612  ************4333           0
# 95508     Mary_Morales@hotmail.com  395-518-4100  ************1821           0
# 95509      MD_Caroline@comcast.net  531-528-1017  ************7860           0
# 95510         Ariana_M@xfinity.com  422-804-6403  ************4482           0
#
# [95511 rows x 35 columns]

# %%
test
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 0      Resort Hotel          7               2015               July
# 1      Resort Hotel          9               2015               July
# 2      Resort Hotel         35               2015               July
# 3      Resort Hotel         18               2015               July
# 4      Resort Hotel         37               2015               July
# ...             ...        ...                ...                ...
# 23874    City Hotel        198               2017             August
# 23875    City Hotel        212               2017             August
# 23876    City Hotel        210               2017             August
# 23877    City Hotel        212               2017             August
# 23878    City Hotel        207               2017             August
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 0                            27                          1
# 1                            27                          1
# 2                            27                          1
# 3                            27                          1
# 4                            27                          1
# ...                         ...                        ...
# 23874                        35                         29
# 23875                        35                         28
# 23876                        35                         28
# 23877                        35                         28
# 23878                        34                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                            0                     1       1       0.0  ...
# 1                            0                     2       2       0.0  ...
# 2                            0                     4       2       0.0  ...
# 3                            0                     4       2       1.0  ...
# 4                            0                     4       2       0.0  ...
# ...                        ...                   ...     ...       ...  ...
# 23874                        1                     5       2       0.0  ...
# 23875                        2                     5       2       0.0  ...
# 23876                        2                     5       2       0.0  ...
# 23877                        2                     5       2       0.0  ...
# 23878                        3                     7       2       0.0  ...
#
#        days_in_waiting_list customer_type     adr required_car_parking_spaces  \
# 0                         0     Transient   75.00                           0
# 1                         0     Transient  103.00                           0
# 2                         0     Transient  145.00                           0
# 3                         0     Transient  154.77                           0
# 4                         0      Contract   97.50                           0
# ...                     ...           ...     ...                         ...
# 23874                     0     Transient  119.17                           0
# 23875                     0     Transient   92.17                           0
# 23876                     0     Transient   85.59                           0
# 23877                     0     Transient   85.59                           0
# 23878                     0     Transient   96.25                           0
#
#       total_of_special_requests  reservation_status               name  \
# 0                             0           Check-Out     Rebecca Parker
# 1                             1           Check-Out      William Velez
# 2                             0           Check-Out       Laurie Smith
# 3                             1           Check-Out    Rachel Friedman
# 4                             0           Check-Out  Dr. Victor Martin
# ...                         ...                 ...                ...
# 23874                         2           Check-Out        Mia Bridges
# 23875                         2           Check-Out  Thomas Richardson
# 23876                         1           Check-Out       Emily Melton
# 23877                         0           Check-Out  Christopher Lewis
# 23878                         2           Check-Out        Erin Benson
#
#                                email  phone-number       credit_card
# 0         Rebecca_Parker@comcast.net  652-885-2745  ************3734
# 1             Velez_William@mail.com  286-669-4333  ************8729
# 2               Smith.Laurie@att.com  804-383-4080  ************5450
# 3            Rachel.F@protonmail.com  435-075-8409  ************9767
# 4              Dr.Martin@xfinity.com  331-430-8824  ************6279
# ...                              ...           ...               ...
# 23874        Bridges.Mia@xfinity.com  656-064-3564  ************7590
# 23875   ThomasRichardson@verizon.com  530-787-9244  ************5743
# 23876       Melton.Emily@verizon.com  176-506-4986  ************8565
# 23877  Lewis.Christopher82@yahoo.com  302-081-9660  ************3901
# 23878          Benson_Erin15@att.com  598-617-2436  ************7834
#
# [23879 rows x 34 columns]

# %%
print(train.shape)
print(test.shape)
# Out:
# (95511, 35)
# (23879, 34)

# %% [markdown]
# ## 결측치찾기

# %%
train.isnull().sum()
# Out:
# hotel                                 0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             386
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                             13117
# company                           90082
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# name                                  0
# email                                 0
# phone-number                          0
# credit_card                           0
# is_canceled                           0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95511 entries, 0 to 95510
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           95511 non-null  object
#  1   lead_time                       95511 non-null  int64
#  2   arrival_date_year               95511 non-null  int64
#  3   arrival_date_month              95511 non-null  object
#  4   arrival_date_week_number        95511 non-null  int64
#  5   arrival_date_day_of_month       95511 non-null  int64
#  6   stays_in_weekend_nights         95511 non-null  int64
#  7   stays_in_week_nights            95511 non-null  int64
#  8   adults                          95511 non-null  int64
#  9   children                        95507 non-null  float64
#  10  babies                          95511 non-null  int64
#  11  meal                            95511 non-null  object
#  12  country                         95125 non-null  object
#  13  market_segment                  95511 non-null  object
#  14  distribution_channel            95511 non-null  object
#  15  is_repeated_guest               95511 non-null  int64
#  16  previous_cancellations          95511 non-null  int64
#  17  previous_bookings_not_canceled  95511 non-null  int64
#  18  reserved_room_type              95511 non-null  object
#  19  assigned_room_type              95511 non-null  object
#  20  booking_changes                 95511 non-null  int64
#  21  deposit_type                    95511 non-null  object
#  22  agent                           82394 non-null  float64
#  23  company                         5429 non-null   float64
#  24  days_in_waiting_list            95511 non-null  int64
#  25  customer_type                   95511 non-null  object
#  26  adr                             95511 non-null  float64
#  27  required_car_parking_spaces     95511 non-null  int64
#  28  total_of_special_requests       95511 non-null  int64
#  29  reservation_status              95511 non-null  object
#  30  name                            95511 non-null  object
#  31  email                           95511 non-null  object
#  32  phone-number                    95511 non-null  object
#  33  credit_card                     95511 non-null  object
#  34  is_canceled                     95511 non-null  int64
# dtypes: float64(4), int64(16), object(15)
# memory usage: 25.5+ MB

# %%
test.isnull().sum()
# Out:
# hotel                                 0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                             102
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                              3223
# company                           22511
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# name                                  0
# email                                 0
# phone-number                          0
# credit_card                           0
# dtype: int64

# %%
train["country"].value_counts()
# Out:
# PRT    38818
# GBR     9681
# FRA     8350
# ESP     6900
# DEU     5790
#        ...
# UMI        1
# DJI        1
# CYM        1
# HND        1
# BDI        1
# Name: country, Length: 172, dtype: int64

# %% [markdown]
# # 결측치 처리 방법
# ## country : 386개, 유럽과 유럽 아닌 곳으로 나누기 -> 상위 8개국이 유럽(country2로 새로운 변수 생성, country는 삭제할 것)
# ## children : 4개 0으로 대체
# ## agent : 평균값으로 대체
# ## company : 결측치 너무 많아서 삭제

# %%
train['children'].fillna(0, inplace = True) # test는 children 결측치 없다.

# %%
train['agent'].fillna(train['agent'].mean(), inplace = True)
test['agent'].fillna(test['agent'].mean(), inplace = True)

# %%
train= train.drop(['company'],axis=1)
test = test.drop(['company'],axis=1)

# %% [markdown]
# # 이상치 제거
# ## 1. adr 가장 큰 값 5400을 뺀 평균으로 바꿔주기
# ## 2. adults 10이 넘는 값 평균으로 바꿔주기

# %%
import matplotlib.pyplot as plt
boxplot=train.boxplot(column=['adr']) # 5000넘는 값 제거

# %%
max(train['adr']) #평균으로 바꿔주기 
(sum(train['adr'])-5400) / 95510
# Out:
# 101.72867186681555

# %%
boxplot=train.boxplot(column=['adults']) # 10이 넘는게 6개라서 평균으로 바꿔주기

# %%
train['adr']=train['adr'].replace(5400,101.728)
train['adults']=train['adults'].replace(55,1.8)
train['adults']=train['adults'].replace(40,1.8)
train['adults']=train['adults'].replace(27,1.8)
train['adults']=train['adults'].replace(26,1.8)
train['adults']=train['adults'].replace(20,1.8)
train['adults']=train['adults'].replace(10,1.8)

# %% [markdown]
# # 새로운 변수 만들기
# ## 1. 성인의수, 미자의수, 아이의 수 세개를 합쳐서 "사람 수" 변수를 새로 생성한다.
# ## 2. 예약한 룸과 실제 배정된 룸이 일치하면 0, 일치하지 않으면 1로 표시하는 변수를 새로 생성한다.

# %%
#1.
train['people']=train['adults']+train['children']+train['babies']
train
test['people']=test['adults']+test['children']+test['babies']
test
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 0      Resort Hotel          7               2015               July
# 1      Resort Hotel          9               2015               July
# 2      Resort Hotel         35               2015               July
# 3      Resort Hotel         18               2015               July
# 4      Resort Hotel         37               2015               July
# ...             ...        ...                ...                ...
# 23874    City Hotel        198               2017             August
# 23875    City Hotel        212               2017             August
# 23876    City Hotel        210               2017             August
# 23877    City Hotel        212               2017             August
# 23878    City Hotel        207               2017             August
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 0                            27                          1
# 1                            27                          1
# 2                            27                          1
# 3                            27                          1
# 4                            27                          1
# ...                         ...                        ...
# 23874                        35                         29
# 23875                        35                         28
# 23876                        35                         28
# 23877                        35                         28
# 23878                        34                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                            0                     1       1       0.0  ...
# 1                            0                     2       2       0.0  ...
# 2                            0                     4       2       0.0  ...
# 3                            0                     4       2       1.0  ...
# 4                            0                     4       2       0.0  ...
# ...                        ...                   ...     ...       ...  ...
# 23874                        1                     5       2       0.0  ...
# 23875                        2                     5       2       0.0  ...
# 23876                        2                     5       2       0.0  ...
# 23877                        2                     5       2       0.0  ...
# 23878                        3                     7       2       0.0  ...
#
#        customer_type     adr required_car_parking_spaces  \
# 0          Transient   75.00                           0
# 1          Transient  103.00                           0
# 2          Transient  145.00                           0
# 3          Transient  154.77                           0
# 4           Contract   97.50                           0
# ...              ...     ...                         ...
# 23874      Transient  119.17                           0
# 23875      Transient   92.17                           0
# 23876      Transient   85.59                           0
# 23877      Transient   85.59                           0
# 23878      Transient   96.25                           0
#
#       total_of_special_requests reservation_status               name  \
# 0                             0          Check-Out     Rebecca Parker
# 1                             1          Check-Out      William Velez
# 2                             0          Check-Out       Laurie Smith
# 3                             1          Check-Out    Rachel Friedman
# 4                             0          Check-Out  Dr. Victor Martin
# ...                         ...                ...                ...
# 23874                         2          Check-Out        Mia Bridges
# 23875                         2          Check-Out  Thomas Richardson
# 23876                         1          Check-Out       Emily Melton
# 23877                         0          Check-Out  Christopher Lewis
# 23878                         2          Check-Out        Erin Benson
#
#                                email  phone-number       credit_card people
# 0         Rebecca_Parker@comcast.net  652-885-2745  ************3734    1.0
# 1             Velez_William@mail.com  286-669-4333  ************8729    2.0
# 2               Smith.Laurie@att.com  804-383-4080  ************5450    2.0
# 3            Rachel.F@protonmail.com  435-075-8409  ************9767    3.0
# 4              Dr.Martin@xfinity.com  331-430-8824  ************6279    2.0
# ...                              ...           ...               ...    ...
# 23874        Bridges.Mia@xfinity.com  656-064-3564  ************7590    2.0
# 23875   ThomasRichardson@verizon.com  530-787-9244  ************5743    2.0
# 23876       Melton.Emily@verizon.com  176-506-4986  ************8565    2.0
# 23877  Lewis.Christopher82@yahoo.com  302-081-9660  ************3901    2.0
# 23878          Benson_Erin15@att.com  598-617-2436  ************7834    2.0
#
# [23879 rows x 34 columns]

# %%
#2. 
train['room']=-1000
for i in range(len(train)):
    if train.loc[i,'assigned_room_type']!=train.loc[i,'reserved_room_type']:
        train.iloc[i,-1]=1
    else:
        train.iloc[i,-1]=0
      
test['room']=-1000
for i in range(len(test)):
    if test.loc[i,'assigned_room_type']!=test.loc[i,'reserved_room_type']:
        test.iloc[i,-1]=1
    else:
        test.iloc[i,-1]=0

# %%
train = train.drop(['reservation_status'], axis = 1)
test = test.drop(['reservation_status'], axis = 1)

# %% [markdown]
# # Encoding
# ## hotel : labelencoding
# ## arrival month : one_hot인코딩 - 1~12월까지 다 있음 column수 변함없음
# ## meal : 삭제
# ## country : 유럽, 유럽 아닌 애들로 묶은 다음에 labelencoding (원래 있던 country는 삭제함)
# ## reserved_room_type : one_hot인코딩
# ## assigned_room_type : one_hot인코딩
# ## deposit_type : one_hot인코딩
# ## customer_type : one_hot인코딩
# ## market_segment :one_hot인코딩
# ## distribution_channel :one_hot인코딩
# ## reservation_status : one_hot인코딩

# %% [markdown]
# ## 원핫인코딩을 하기 전에 shape이 맞지 않아서 train과 test의 column을 맞추기 위해 행 제거를 하였다.
# ### assigned_room_type : train에서 L이 있는 행 전체 삭제(1개)
# ### market_segment : train에서 Undefined 행 전체 삭제(2개)
# ### distribution_channel : train에서 Undefined 행 전체 삭제(5개)

# %%
train[train['assigned_room_type'] == 'L'] #11524번 index
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 11524  Resort Hotel          0               2015               July
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 11524                        29                         17
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 11524                        0                     1     2.0       0.0  ...
#
#        adr required_car_parking_spaces total_of_special_requests         name  \
# 11524  8.0                           0                         0  Susan James
#
#                          email  phone-number       credit_card  is_canceled  \
# 11524  Susan.James@outlook.com  105-006-1539  ************7302            1
#
#       people room
# 11524    2.0    0
#
# [1 rows x 35 columns]

# %%
train[train['market_segment'] == 'Undefined'] # 32464, 32531 아래랑 겹침!
# Out:
#             hotel  lead_time  arrival_date_year arrival_date_month  \
# 32464  City Hotel          2               2015             August
# 32531  City Hotel          1               2015             August
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 32464                        32                          3
# 32531                        32                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 32464                        1                     0     2.0       0.0  ...
# 32531                        0                     2     3.0       0.0  ...
#
#         adr required_car_parking_spaces total_of_special_requests  \
# 32464  12.0                           0                         1
# 32531  18.0                           0                         2
#
#                name                     email  phone-number       credit_card  \
# 32464  Craig Campos      CraigCampos@mail.com  820-622-9854  ************7219
# 32531  Frank Burton  Frank.Burton@comcast.net  395-084-3601  ************6190
#
#        is_canceled people room
# 32464            1    2.0    0
# 32531            1    3.0    0
#
# [2 rows x 35 columns]

# %%
train[train['distribution_channel'] == 'Undefined'] #11696, 32464, 32519, 32531, 32905
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 11696  Resort Hotel        103               2015               July
# 32464    City Hotel          2               2015             August
# 32519    City Hotel          1               2015             August
# 32531    City Hotel          1               2015             August
# 32905    City Hotel          8               2015             August
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 11696                        28                          5
# 32464                        32                          3
# 32519                        32                          5
# 32531                        32                          5
# 32905                        33                         13
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 11696                        2                     3     2.0       1.0  ...
# 32464                        1                     0     2.0       0.0  ...
# 32519                        0                     2     2.0       0.0  ...
# 32531                        0                     2     3.0       0.0  ...
# 32905                        2                     5     2.0       0.0  ...
#
#          adr required_car_parking_spaces total_of_special_requests  \
# 11696  112.7                           1                         2
# 32464   12.0                           0                         1
# 32519   12.0                           0                         1
# 32531   18.0                           0                         2
# 32905   76.5                           0                         1
#
#                 name                     email  phone-number  \
# 11696    Kevin Davis        Kevin.D@yandex.com  841-387-5067
# 32464   Craig Campos      CraigCampos@mail.com  820-622-9854
# 32519   David Murphy  David.Murphy94@yahoo.com  231-438-6733
# 32531   Frank Burton  Frank.Burton@comcast.net  395-084-3601
# 32905  Jerry Roberts      JRoberts@hotmail.com  979-355-3554
#
#             credit_card  is_canceled people room
# 11696  ************6010            0    3.0    0
# 32464  ************7219            1    2.0    0
# 32519  ************8925            1    2.0    0
# 32531  ************6190            1    3.0    0
# 32905  ************5648            1    2.0    0
#
# [5 rows x 35 columns]

# %%
train.drop(index = [11524,11696, 32464, 32519, 32531, 32905], inplace = True)

# %%
country2 =(train['country'].str.contains('PRT'or'GBR'or'FRA'or'ESP'or'DEU'or'ITA'or'IRL'or'BEL'))
train.insert(34, 'country2', country2) 
country2 =(test['country'].str.contains('PRT'or'GBR'or'FRA'or'ESP'or'DEU'or'ITA'or'IRL'or'BEL'))
test.insert(33, 'country2', country2)

# %%
label_encoder = LabelEncoder()
train['hotel'] = label_encoder.fit_transform(train['hotel'])
label_encoder = LabelEncoder()
test['hotel'] = label_encoder.fit_transform(test['hotel'])

# %%
# 유럽/유럽 아닌 애들로 묶어준거 label인코딩
label_encoder = LabelEncoder()
train['country2'] = label_encoder.fit_transform(train['country2'])
label_encoder = LabelEncoder()
test['country2'] = label_encoder.fit_transform(test['country2'])

# %%
# 원핫인코딩
train = pd.get_dummies(data=train, columns=['arrival_date_month','market_segment','distribution_channel','reserved_room_type','assigned_room_type'
,'deposit_type', 'customer_type'])

test = pd.get_dummies(data=test, columns=['arrival_date_month','market_segment','distribution_channel','reserved_room_type','assigned_room_type'
,'deposit_type', 'customer_type'])

# %% [markdown]
# # 필요없는 칼럼 삭제
# ## email, name, phone_number, credit_card, country 삭제

# %%
train = train.drop(['email', 'name','phone-number','credit_card','meal','country'], axis = 1)
test = test.drop(['email', 'name','phone-number','credit_card','meal','country'], axis = 1)

# %%
print(train.shape)
print(test.shape)
# Out:
# (95505, 74)
# (23879, 73)

# %%
cancel=train['is_canceled'].unique()
np.sort(cancel)
# Out:
# array([0, 1], dtype=int64)

# %%
train.groupby('is_canceled').count().iloc[:,0]
# Out:
# is_canceled
# 0    60131
# 1    35374
# Name: hotel, dtype: int64

# %%
plt.rcParams['figure.figsize'] = [25,10]
sns.countplot('is_canceled' , data=train)
plt.title('canceld by count', fontsize=30)
plt.xlabel('target(cancel)', fontsize=15)
plt.ylabel('count', fontsize=15)
plt.show()
# Out:
# C:\Users\lyr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 모델링

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier


X = train.drop(['is_canceled'],axis=1)
y = train.is_canceled
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 99)

# %%
print(X.shape)
print(y.shape)
# Out:
# (95505, 73)
# (95505,)

# %% [markdown]
# ##XGBoost

# %%
from xgboost import XGBClassifier
evals = [(X_test, y_test)]
xgb_wrapper = XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=6)

xgb_wrapper.fit(X_train , y_train, early_stopping_rounds=100, eval_set=evals, eval_metric="logloss",  verbose=True)
w_preds = xgb_wrapper.predict(X_test)
print(w_preds)

xgb_wrapper.fit(X_train,y_train)
y_pred = xgb_wrapper.predict(test)
# Out:
# [0]	validation_0-logloss:0.68816
# [1]	validation_0-logloss:0.68327
# [2]	validation_0-logloss:0.67848
# [3]	validation_0-logloss:0.67378
# [4]	validation_0-logloss:0.66916
# [5]	validation_0-logloss:0.66464
# [6]	validation_0-logloss:0.66021
# [7]	validation_0-logloss:0.65587
# [8]	validation_0-logloss:0.65161
# [9]	validation_0-logloss:0.64743
# [10]	validation_0-logloss:0.64334
# [11]	validation_0-logloss:0.63931
# [12]	validation_0-logloss:0.63536
# [13]	validation_0-logloss:0.63148
# [14]	validation_0-logloss:0.62766
# [15]	validation_0-logloss:0.62391
# [16]	validation_0-logloss:0.62023
# [17]	validation_0-logloss:0.61661
# [18]	validation_0-logloss:0.61306
# [19]	validation_0-logloss:0.60957
# [20]	validation_0-logloss:0.60614
# [21]	validation_0-logloss:0.60276
# [22]	validation_0-logloss:0.59945
# [23]	validation_0-logloss:0.59620
# [24]	validation_0-logloss:0.59299
# [25]	validation_0-logloss:0.58983
# [26]	validation_0-logloss:0.58673
# [27]	validation_0-logloss:0.58368
# [28]	validation_0-logloss:0.58067
# [29]	validation_0-logloss:0.57770
# [30]	validation_0-logloss:0.57476
# [31]	validation_0-logloss:0.57186
# [32]	validation_0-logloss:0.56905
# [33]	validation_0-logloss:0.56628
# [34]	validation_0-logloss:0.56356
# [35]	validation_0-logloss:0.56089
# [36]	validation_0-logloss:0.55826
# [37]	validation_0-logloss:0.55567
# [38]	validation_0-logloss:0.55311
# [39]	validation_0-logloss:0.55060
# [40]	validation_0-logloss:0.54812
# [41]	validation_0-logloss:0.54569
# [42]	validation_0-logloss:0.54330
# [43]	validation_0-logloss:0.54093
# [44]	validation_0-logloss:0.53862
# [45]	validation_0-logloss:0.53631
# [46]	validation_0-logloss:0.53406
# [47]	validation_0-logloss:0.53188
# [48]	validation_0-logloss:0.52969
# [49]	validation_0-logloss:0.52753
# [50]	validation_0-logloss:0.52545
# [51]	validation_0-logloss:0.52320
# [52]	validation_0-logloss:0.52118
# [53]	validation_0-logloss:0.51898
# [54]	validation_0-logloss:0.51683
# [55]	validation_0-logloss:0.51488
# [56]	validation_0-logloss:0.51278
# [57]	validation_0-logloss:0.51089
# [58]	validation_0-logloss:0.50885
# [59]	validation_0-logloss:0.50702
# [60]	validation_0-logloss:0.50502
# [61]	validation_0-logloss:0.50324
# [62]	validation_0-logloss:0.50131
# [63]	validation_0-logloss:0.49940
# [64]	validation_0-logloss:0.49769
# [65]	validation_0-logloss:0.49582
# [66]	validation_0-logloss:0.49414
# [67]	validation_0-logloss:0.49249
# [68]	validation_0-logloss:0.49071
# [69]	validation_0-logloss:0.48909
# [70]	validation_0-logloss:0.48753
# [71]	validation_0-logloss:0.48596
# [72]	validation_0-logloss:0.48442
# [73]	validation_0-logloss:0.48273
# [74]	validation_0-logloss:0.48123
# [75]	validation_0-logloss:0.47977
# [76]	validation_0-logloss:0.47833
# [77]	validation_0-logloss:0.47684
# [78]	validation_0-logloss:0.47526
# [79]	validation_0-logloss:0.47385
# [80]	validation_0-logloss:0.47241
# [81]	validation_0-logloss:0.47088
# [82]	validation_0-logloss:0.46953
# [83]	validation_0-logloss:0.46814
# [84]	validation_0-logloss:0.46667
# [85]	validation_0-logloss:0.46536
# [86]	validation_0-logloss:0.46403
# [87]	validation_0-logloss:0.46259
# [88]	validation_0-logloss:0.46135
# [89]	validation_0-logloss:0.46006
# [90]	validation_0-logloss:0.45883
# [91]	validation_0-logloss:0.45763
# [92]	validation_0-logloss:0.45638
# [93]	validation_0-logloss:0.45504
# [94]	validation_0-logloss:0.45388
# [95]	validation_0-logloss:0.45273
# [96]	validation_0-logloss:0.45155
# [97]	validation_0-logloss:0.45026
# [98]	validation_0-logloss:0.44915
# [99]	validation_0-logloss:0.44800
# [0 0 0 ... 0 1 0]
# [18:46:09] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
from xgboost import XGBClassifier

model = XGBClassifier(random_state=42)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)

print(accuracy)
# Out:
# C:\Users\lyr\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:46:39] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.8805298151929218

# %%
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier(random_state=42)
model.fit(X_train,y_train)
pred = model.predict(X_test)
accuracy = accuracy_score(y_test,pred)

print(accuracy)
# Out:
# 0.8899010523009266

# %%
from lightgbm import LGBMClassifier
lgbm_wrapper = LGBMClassifier(n_estimators=400, learning_rate=0.1,max_depth = 10)
lgbm_wrapper.fit(X_train,y_train, early_stopping_rounds=100, eval_metric = 'logloss',
                  eval_set = evals, verbose=True)
l_pred = lgbm_wrapper.predict(X_test)
print('LightGBM 정확도 : %.4f'%accuracy_score(y_test, l_pred))
# Out:
# C:\Users\lyr\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lyr\anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.608537
# [2]	valid_0's binary_logloss: 0.568267
# [3]	valid_0's binary_logloss: 0.535277
# [4]	valid_0's binary_logloss: 0.507444
# [5]	valid_0's binary_logloss: 0.484178
# [6]	valid_0's binary_logloss: 0.464294
# [7]	valid_0's binary_logloss: 0.446442
# [8]	valid_0's binary_logloss: 0.431079
# [9]	valid_0's binary_logloss: 0.417898
# [10]	valid_0's binary_logloss: 0.405248
# [11]	valid_0's binary_logloss: 0.3949
# [12]	valid_0's binary_logloss: 0.385718
# [13]	valid_0's binary_logloss: 0.377346
# [14]	valid_0's binary_logloss: 0.369837
# [15]	valid_0's binary_logloss: 0.363212
# [16]	valid_0's binary_logloss: 0.356949
# [17]	valid_0's binary_logloss: 0.350847
# [18]	valid_0's binary_logloss: 0.345295
# [19]	valid_0's binary_logloss: 0.341026
# [20]	valid_0's binary_logloss: 0.336682
# [21]	valid_0's binary_logloss: 0.332093
# [22]	valid_0's binary_logloss: 0.328538
# [23]	valid_0's binary_logloss: 0.324793
# [24]	valid_0's binary_logloss: 0.322032
# [25]	valid_0's binary_logloss: 0.318881
# [26]	valid_0's binary_logloss: 0.31576
# [27]	valid_0's binary_logloss: 0.312859
# [28]	valid_0's binary_logloss: 0.309901
# [29]	valid_0's binary_logloss: 0.307536
# [30]	valid_0's binary_logloss: 0.305557
# [31]	valid_0's binary_logloss: 0.304065
# [32]	valid_0's binary_logloss: 0.302415
# [33]	valid_0's binary_logloss: 0.30117
# [34]	valid_0's binary_logloss: 0.299227
# [35]	valid_0's binary_logloss: 0.297799
# [36]	valid_0's binary_logloss: 0.2966
# [37]	valid_0's binary_logloss: 0.295348
# [38]	valid_0's binary_logloss: 0.294072
# [39]	valid_0's binary_logloss: 0.29243
# [40]	valid_0's binary_logloss: 0.291491
# [41]	valid_0's binary_logloss: 0.29037
# [42]	valid_0's binary_logloss: 0.289496
# [43]	valid_0's binary_logloss: 0.288622
# [44]	valid_0's binary_logloss: 0.28771
# [45]	valid_0's binary_logloss: 0.28676
# [46]	valid_0's binary_logloss: 0.285891
# [47]	valid_0's binary_logloss: 0.285193
# [48]	valid_0's binary_logloss: 0.284349
# [49]	valid_0's binary_logloss: 0.283622
# [50]	valid_0's binary_logloss: 0.283048
# [51]	valid_0's binary_logloss: 0.282498
# [52]	valid_0's binary_logloss: 0.28159
# [53]	valid_0's binary_logloss: 0.280945
# [54]	valid_0's binary_logloss: 0.280285
# [55]	valid_0's binary_logloss: 0.279731
# [56]	valid_0's binary_logloss: 0.279226
# [57]	valid_0's binary_logloss: 0.278789
# [58]	valid_0's binary_logloss: 0.278454
# [59]	valid_0's binary_logloss: 0.277841
# [60]	valid_0's binary_logloss: 0.276986
# [61]	valid_0's binary_logloss: 0.276586
# [62]	valid_0's binary_logloss: 0.276217
# [63]	valid_0's binary_logloss: 0.275892
# [64]	valid_0's binary_logloss: 0.274894
# [65]	valid_0's binary_logloss: 0.274497
# [66]	valid_0's binary_logloss: 0.273978
# [67]	valid_0's binary_logloss: 0.273571
# [68]	valid_0's binary_logloss: 0.273224
# [69]	valid_0's binary_logloss: 0.27286
# [70]	valid_0's binary_logloss: 0.271901
# [71]	valid_0's binary_logloss: 0.271497
# [72]	valid_0's binary_logloss: 0.270969
# [73]	valid_0's binary_logloss: 0.270284
# [74]	valid_0's binary_logloss: 0.269956
# [75]	valid_0's binary_logloss: 0.269659
# [76]	valid_0's binary_logloss: 0.269268
# [77]	valid_0's binary_logloss: 0.268617
# [78]	valid_0's binary_logloss: 0.268251
# [79]	valid_0's binary_logloss: 0.26769
# [80]	valid_0's binary_logloss: 0.267317
# [81]	valid_0's binary_logloss: 0.267077
# [82]	valid_0's binary_logloss: 0.266806
# [83]	valid_0's binary_logloss: 0.266599
# [84]	valid_0's binary_logloss: 0.266356
# [85]	valid_0's binary_logloss: 0.266076
# [86]	valid_0's binary_logloss: 0.265874
# [87]	valid_0's binary_logloss: 0.265363
# [88]	valid_0's binary_logloss: 0.265127
# [89]	valid_0's binary_logloss: 0.264864
# [90]	valid_0's binary_logloss: 0.264583
# [91]	valid_0's binary_logloss: 0.264224
# [92]	valid_0's binary_logloss: 0.263987
# [93]	valid_0's binary_logloss: 0.263778
# [94]	valid_0's binary_logloss: 0.263631
# [95]	valid_0's binary_logloss: 0.263401
# [96]	valid_0's binary_logloss: 0.263226
# [97]	valid_0's binary_logloss: 0.262848
# [98]	valid_0's binary_logloss: 0.262577
# [99]	valid_0's binary_logloss: 0.262418
# [100]	valid_0's binary_logloss: 0.262308
# [101]	valid_0's binary_logloss: 0.261786
# [102]	valid_0's binary_logloss: 0.261606
# [103]	valid_0's binary_logloss: 0.261408
# [104]	valid_0's binary_logloss: 0.261221
# [105]	valid_0's binary_logloss: 0.26099
# [106]	valid_0's binary_logloss: 0.260784
# [107]	valid_0's binary_logloss: 0.260592
# [108]	valid_0's binary_logloss: 0.260272
# [109]	valid_0's binary_logloss: 0.259989
# [110]	valid_0's binary_logloss: 0.25982
# [111]	valid_0's binary_logloss: 0.259627
# [112]	valid_0's binary_logloss: 0.259473
# [113]	valid_0's binary_logloss: 0.259286
# [114]	valid_0's binary_logloss: 0.25904
# [115]	valid_0's binary_logloss: 0.258384
# [116]	valid_0's binary_logloss: 0.258201
# [117]	valid_0's binary_logloss: 0.257982
# [118]	valid_0's binary_logloss: 0.257787
# [119]	valid_0's binary_logloss: 0.257677
# [120]	valid_0's binary_logloss: 0.257458
# [121]	valid_0's binary_logloss: 0.257362
# [122]	valid_0's binary_logloss: 0.25715
# [123]	valid_0's binary_logloss: 0.256962
# [124]	valid_0's binary_logloss: 0.256793
# [125]	valid_0's binary_logloss: 0.256607
# [126]	valid_0's binary_logloss: 0.25613
# [127]	valid_0's binary_logloss: 0.255894
# [128]	valid_0's binary_logloss: 0.255697
# [129]	valid_0's binary_logloss: 0.255323
# [130]	valid_0's binary_logloss: 0.255151
# [131]	valid_0's binary_logloss: 0.255004
# [132]	valid_0's binary_logloss: 0.254845
# [133]	valid_0's binary_logloss: 0.254544
# [134]	valid_0's binary_logloss: 0.254314
# [135]	valid_0's binary_logloss: 0.254245
# [136]	valid_0's binary_logloss: 0.254008
# [137]	valid_0's binary_logloss: 0.253865
# [138]	valid_0's binary_logloss: 0.253468
# [139]	valid_0's binary_logloss: 0.253302
# [140]	valid_0's binary_logloss: 0.253122
# [141]	valid_0's binary_logloss: 0.253029
# [142]	valid_0's binary_logloss: 0.252924
# [143]	valid_0's binary_logloss: 0.252542
# [144]	valid_0's binary_logloss: 0.252427
# [145]	valid_0's binary_logloss: 0.252274
# [146]	valid_0's binary_logloss: 0.251939
# [147]	valid_0's binary_logloss: 0.251875
# [148]	valid_0's binary_logloss: 0.25179
# [149]	valid_0's binary_logloss: 0.251631
# [150]	valid_0's binary_logloss: 0.251464
# [151]	valid_0's binary_logloss: 0.251226
# [152]	valid_0's binary_logloss: 0.251029
# [153]	valid_0's binary_logloss: 0.250847
# [154]	valid_0's binary_logloss: 0.250506
# [155]	valid_0's binary_logloss: 0.250303
# [156]	valid_0's binary_logloss: 0.250007
# [157]	valid_0's binary_logloss: 0.249713
# [158]	valid_0's binary_logloss: 0.249566
# [159]	valid_0's binary_logloss: 0.249295
# [160]	valid_0's binary_logloss: 0.249117
# [161]	valid_0's binary_logloss: 0.248987
# [162]	valid_0's binary_logloss: 0.248815
# [163]	valid_0's binary_logloss: 0.24865
# [164]	valid_0's binary_logloss: 0.248504
# [165]	valid_0's binary_logloss: 0.248334
# [166]	valid_0's binary_logloss: 0.248247
# [167]	valid_0's binary_logloss: 0.248024
# [168]	valid_0's binary_logloss: 0.247836
# [169]	valid_0's binary_logloss: 0.247681
# [170]	valid_0's binary_logloss: 0.24753
# [171]	valid_0's binary_logloss: 0.247379
# [172]	valid_0's binary_logloss: 0.247164
# [173]	valid_0's binary_logloss: 0.246971
# [174]	valid_0's binary_logloss: 0.24653
# [175]	valid_0's binary_logloss: 0.246365
# [176]	valid_0's binary_logloss: 0.246309
# [177]	valid_0's binary_logloss: 0.246232
# [178]	valid_0's binary_logloss: 0.246108
# [179]	valid_0's binary_logloss: 0.245898
# [180]	valid_0's binary_logloss: 0.245639
# [181]	valid_0's binary_logloss: 0.245494
# [182]	valid_0's binary_logloss: 0.245286
# [183]	valid_0's binary_logloss: 0.245072
# [184]	valid_0's binary_logloss: 0.244894
# [185]	valid_0's binary_logloss: 0.244591
# [186]	valid_0's binary_logloss: 0.244397
# [187]	valid_0's binary_logloss: 0.244293
# [188]	valid_0's binary_logloss: 0.244117
# [189]	valid_0's binary_logloss: 0.243731
# [190]	valid_0's binary_logloss: 0.243541
# [191]	valid_0's binary_logloss: 0.243475
# [192]	valid_0's binary_logloss: 0.243353
# [193]	valid_0's binary_logloss: 0.243124
# [194]	valid_0's binary_logloss: 0.242914
# [195]	valid_0's binary_logloss: 0.242777
# [196]	valid_0's binary_logloss: 0.242504
# [197]	valid_0's binary_logloss: 0.242413
# [198]	valid_0's binary_logloss: 0.242298
# [199]	valid_0's binary_logloss: 0.242228
# [200]	valid_0's binary_logloss: 0.242065
# [201]	valid_0's binary_logloss: 0.241846
# [202]	valid_0's binary_logloss: 0.24168
# [203]	valid_0's binary_logloss: 0.241493
# [204]	valid_0's binary_logloss: 0.241246
# [205]	valid_0's binary_logloss: 0.241107
# [206]	valid_0's binary_logloss: 0.241021
# [207]	valid_0's binary_logloss: 0.24085
# [208]	valid_0's binary_logloss: 0.240731
# [209]	valid_0's binary_logloss: 0.24055
# [210]	valid_0's binary_logloss: 0.240427
# [211]	valid_0's binary_logloss: 0.240294
# [212]	valid_0's binary_logloss: 0.24023
# [213]	valid_0's binary_logloss: 0.240001
# [214]	valid_0's binary_logloss: 0.239805
# [215]	valid_0's binary_logloss: 0.239709
# [216]	valid_0's binary_logloss: 0.239561
# [217]	valid_0's binary_logloss: 0.239362
# [218]	valid_0's binary_logloss: 0.239257
# [219]	valid_0's binary_logloss: 0.239113
# [220]	valid_0's binary_logloss: 0.239064
# [221]	valid_0's binary_logloss: 0.238919
# [222]	valid_0's binary_logloss: 0.2388
# [223]	valid_0's binary_logloss: 0.238618
# [224]	valid_0's binary_logloss: 0.238397
# [225]	valid_0's binary_logloss: 0.238192
# [226]	valid_0's binary_logloss: 0.238065
# [227]	valid_0's binary_logloss: 0.237982
# [228]	valid_0's binary_logloss: 0.237802
# [229]	valid_0's binary_logloss: 0.237674
# [230]	valid_0's binary_logloss: 0.237509
# [231]	valid_0's binary_logloss: 0.237323
# [232]	valid_0's binary_logloss: 0.237257
# [233]	valid_0's binary_logloss: 0.237156
# [234]	valid_0's binary_logloss: 0.236956
# [235]	valid_0's binary_logloss: 0.236866
# [236]	valid_0's binary_logloss: 0.236657
# [237]	valid_0's binary_logloss: 0.236454
# [238]	valid_0's binary_logloss: 0.236371
# [239]	valid_0's binary_logloss: 0.236245
# [240]	valid_0's binary_logloss: 0.236214
# [241]	valid_0's binary_logloss: 0.236095
# [242]	valid_0's binary_logloss: 0.235981
# [243]	valid_0's binary_logloss: 0.235839
# [244]	valid_0's binary_logloss: 0.235663
# [245]	valid_0's binary_logloss: 0.235519
# [246]	valid_0's binary_logloss: 0.235358
# [247]	valid_0's binary_logloss: 0.235145
# [248]	valid_0's binary_logloss: 0.235048
# [249]	valid_0's binary_logloss: 0.234936
# [250]	valid_0's binary_logloss: 0.234843
# [251]	valid_0's binary_logloss: 0.23472
# [252]	valid_0's binary_logloss: 0.234612
# [253]	valid_0's binary_logloss: 0.23447
# [254]	valid_0's binary_logloss: 0.234111
# [255]	valid_0's binary_logloss: 0.233941
# [256]	valid_0's binary_logloss: 0.233893
# [257]	valid_0's binary_logloss: 0.233796
# [258]	valid_0's binary_logloss: 0.233653
# [259]	valid_0's binary_logloss: 0.233504
# [260]	valid_0's binary_logloss: 0.233399
# [261]	valid_0's binary_logloss: 0.233259
# [262]	valid_0's binary_logloss: 0.233176
# [263]	valid_0's binary_logloss: 0.233022
# [264]	valid_0's binary_logloss: 0.232859
# [265]	valid_0's binary_logloss: 0.232735
# [266]	valid_0's binary_logloss: 0.232571
# [267]	valid_0's binary_logloss: 0.232446
# [268]	valid_0's binary_logloss: 0.232254
# [269]	valid_0's binary_logloss: 0.232106
# [270]	valid_0's binary_logloss: 0.231975
# [271]	valid_0's binary_logloss: 0.231826
# [272]	valid_0's binary_logloss: 0.231805
# [273]	valid_0's binary_logloss: 0.231701
# [274]	valid_0's binary_logloss: 0.231527
# [275]	valid_0's binary_logloss: 0.23139
# [276]	valid_0's binary_logloss: 0.231264
# [277]	valid_0's binary_logloss: 0.231113
# [278]	valid_0's binary_logloss: 0.230987
# [279]	valid_0's binary_logloss: 0.230868
# [280]	valid_0's binary_logloss: 0.230734
# [281]	valid_0's binary_logloss: 0.230577
# [282]	valid_0's binary_logloss: 0.230461
# [283]	valid_0's binary_logloss: 0.230317
# [284]	valid_0's binary_logloss: 0.230281
# [285]	valid_0's binary_logloss: 0.230224
# [286]	valid_0's binary_logloss: 0.230102
# [287]	valid_0's binary_logloss: 0.229984
# [288]	valid_0's binary_logloss: 0.229701
# [289]	valid_0's binary_logloss: 0.229593
# [290]	valid_0's binary_logloss: 0.229562
# [291]	valid_0's binary_logloss: 0.229486
# [292]	valid_0's binary_logloss: 0.229292
# [293]	valid_0's binary_logloss: 0.229146
# [294]	valid_0's binary_logloss: 0.229001
# [295]	valid_0's binary_logloss: 0.228902
# [296]	valid_0's binary_logloss: 0.228595
# [297]	valid_0's binary_logloss: 0.228483
# [298]	valid_0's binary_logloss: 0.228327
# [299]	valid_0's binary_logloss: 0.228255
# [300]	valid_0's binary_logloss: 0.227969
# [301]	valid_0's binary_logloss: 0.227895
# [302]	valid_0's binary_logloss: 0.227795
# [303]	valid_0's binary_logloss: 0.227697
# [304]	valid_0's binary_logloss: 0.227489
# [305]	valid_0's binary_logloss: 0.227319
# [306]	valid_0's binary_logloss: 0.227224
# [307]	valid_0's binary_logloss: 0.227079
# [308]	valid_0's binary_logloss: 0.226984
# [309]	valid_0's binary_logloss: 0.226747
# [310]	valid_0's binary_logloss: 0.226657
# [311]	valid_0's binary_logloss: 0.226397
# [312]	valid_0's binary_logloss: 0.226309
# [313]	valid_0's binary_logloss: 0.22615
# [314]	valid_0's binary_logloss: 0.226092
# [315]	valid_0's binary_logloss: 0.22599
# [316]	valid_0's binary_logloss: 0.225921
# [317]	valid_0's binary_logloss: 0.225818
# [318]	valid_0's binary_logloss: 0.225618
# [319]	valid_0's binary_logloss: 0.225483
# [320]	valid_0's binary_logloss: 0.225378
# [321]	valid_0's binary_logloss: 0.225288
# [322]	valid_0's binary_logloss: 0.225176
# [323]	valid_0's binary_logloss: 0.225065
# [324]	valid_0's binary_logloss: 0.224978
# [325]	valid_0's binary_logloss: 0.224806
# [326]	valid_0's binary_logloss: 0.224681
# [327]	valid_0's binary_logloss: 0.224641
# [328]	valid_0's binary_logloss: 0.224554
# [329]	valid_0's binary_logloss: 0.224532
# [330]	valid_0's binary_logloss: 0.224484
# [331]	valid_0's binary_logloss: 0.224385
# [332]	valid_0's binary_logloss: 0.224327
# [333]	valid_0's binary_logloss: 0.224234
# [334]	valid_0's binary_logloss: 0.224106
# [335]	valid_0's binary_logloss: 0.223929
# [336]	valid_0's binary_logloss: 0.223879
# [337]	valid_0's binary_logloss: 0.223782
# [338]	valid_0's binary_logloss: 0.223574
# [339]	valid_0's binary_logloss: 0.223473
# [340]	valid_0's binary_logloss: 0.223371
# [341]	valid_0's binary_logloss: 0.223206
# [342]	valid_0's binary_logloss: 0.223111
# [343]	valid_0's binary_logloss: 0.223039
# [344]	valid_0's binary_logloss: 0.223013
# [345]	valid_0's binary_logloss: 0.222967
# [346]	valid_0's binary_logloss: 0.222833
# [347]	valid_0's binary_logloss: 0.222765
# [348]	valid_0's binary_logloss: 0.222662
# [349]	valid_0's binary_logloss: 0.222558
# [350]	valid_0's binary_logloss: 0.222399
# [351]	valid_0's binary_logloss: 0.222253
# [352]	valid_0's binary_logloss: 0.222027
# [353]	valid_0's binary_logloss: 0.221939
# [354]	valid_0's binary_logloss: 0.221767
# [355]	valid_0's binary_logloss: 0.221649
# [356]	valid_0's binary_logloss: 0.221519
# [357]	valid_0's binary_logloss: 0.221421
# [358]	valid_0's binary_logloss: 0.221409
# [359]	valid_0's binary_logloss: 0.221345
# [360]	valid_0's binary_logloss: 0.221269
# [361]	valid_0's binary_logloss: 0.221136
# [362]	valid_0's binary_logloss: 0.221025
# [363]	valid_0's binary_logloss: 0.220896
# [364]	valid_0's binary_logloss: 0.220773
# [365]	valid_0's binary_logloss: 0.220675
# [366]	valid_0's binary_logloss: 0.220586
# [367]	valid_0's binary_logloss: 0.220396
# [368]	valid_0's binary_logloss: 0.220308
# [369]	valid_0's binary_logloss: 0.220219
# [370]	valid_0's binary_logloss: 0.220125
# [371]	valid_0's binary_logloss: 0.219983
# [372]	valid_0's binary_logloss: 0.219816
# [373]	valid_0's binary_logloss: 0.219653
# [374]	valid_0's binary_logloss: 0.219482
# [375]	valid_0's binary_logloss: 0.219374
# [376]	valid_0's binary_logloss: 0.219322
# [377]	valid_0's binary_logloss: 0.219195
# [378]	valid_0's binary_logloss: 0.21909
# [379]	valid_0's binary_logloss: 0.21901
# [380]	valid_0's binary_logloss: 0.218897
# [381]	valid_0's binary_logloss: 0.218835
# [382]	valid_0's binary_logloss: 0.218745
# [383]	valid_0's binary_logloss: 0.218587
# [384]	valid_0's binary_logloss: 0.218376
# [385]	valid_0's binary_logloss: 0.218257
# [386]	valid_0's binary_logloss: 0.218093
# [387]	valid_0's binary_logloss: 0.218011
# [388]	valid_0's binary_logloss: 0.217923
# [389]	valid_0's binary_logloss: 0.217824
# [390]	valid_0's binary_logloss: 0.217755
# [391]	valid_0's binary_logloss: 0.217595
# [392]	valid_0's binary_logloss: 0.217514
# [393]	valid_0's binary_logloss: 0.217355
# [394]	valid_0's binary_logloss: 0.217294
# [395]	valid_0's binary_logloss: 0.217168
# [396]	valid_0's binary_logloss: 0.217024
# [397]	valid_0's binary_logloss: 0.216883
# [398]	valid_0's binary_logloss: 0.21671
# [399]	valid_0's binary_logloss: 0.216651
# [400]	valid_0's binary_logloss: 0.216586
# LightGBM 정확도 : 0.8840

# %%
model = AdaBoostClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
pred = model.predict(X_test)
print(accuracy_score(pred, y_test))
# Out:
# 0.8379142453274697

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(random_state=42)
grid_parameters={'n_estimators':[100,200],'learning_rate':[0.2,0.4]}
grid_ada = GridSearchCV(ada, param_grid=grid_parameters, cv = 3 , refit=True)
grid_ada.fit(X_test,y_test)
print("GridSearchCV 최고 정확도:",grid_ada.best_score_)
# Out:
# GridSearchCV 최고 정확도: 0.8346683419716244

# %%
from sklearn.model_selection import GridSearchCV

params = {
     'n_estimators':[100],
     'max_depth' : [6, 8, 10, 12], 
     'min_samples_leaf' : [8, 12, 18 ],
     'min_samples_split' : [8, 16, 20]
 }
 # RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf , param_grid=params , cv=2, n_jobs=-1 )
grid_cv.fit(X_train , y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 12, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 100}
# 최고 예측 정확도: 0.8547

# %%
#데이터 분포 확인
interest_coloumns = train.columns[1:]
plt.style.use('fivethirtyeight')
fig, ax =plt.subplots(2, 4, figsize = (25, 10))
fig.suptitle('Histogram of interesting features', fontsize=40)
column_idx = 0
for i in range(2):
    for j in range(4):
        ax[i][j].hist(train[interest_coloumns[column_idx]], bins=30, color='#eaa18a', edgecolor='#7bcabf')
        ax[i][j].set_title(interest_coloumns[column_idx])
        ax[i][j].axvline(data_description[interest_coloumns[column_idx]]['mean'], c='#f55354', label = f"mean = {round(data_description[interest_coloumns[column_idx]]['mean'], 2)}")
        ax[i][j].axvline(data_description[interest_coloumns[column_idx]]['50%'], c='#518d7d', label = f"median = {round(data_description[interest_coloumns[column_idx]]['50%'], 2)}")
        ax[i][j].legend()
        column_idx += 1

# %%
def visualize(axx, yfield):
  sns.regplot(x='is_canceled', y=yfield, data=train,  color='#eaa18a', line_kws=  {'color': '#f55354'} , ax = axx) # regplot을 이용하여 추세선과 산점도 그래프를 그려줍니다.
  axx.set_title(yfield)

figure, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(nrows=2, ncols=4)
figure.set_size_inches(20,12)
figure.suptitle('Correlation between target and features', fontsize=40)
for i in range(len(train.columns[1:-1])):
  visualize(eval(f'ax{i+1}'), train.columns[i+1])
